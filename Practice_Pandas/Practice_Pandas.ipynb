# %% [markdown]
# **นางสาวจิตรลดา โยธินทะ 6510405377**

# %% [markdown]
# # 1. โหลดไฟล์ที่ชื่อ olympic_cleaned.csv ขึ้นมาใน DataFrame ที่ชื่อ medals

# %%
import pandas as pd

# %%
medals = pd.read_csv("olympics_cleaned.csv")
medals
# Out:
#                               Country Code  SummerGame  SummerGold  \
# 0                         Afghanistan  AFG          13           0
# 1                             Algeria  ALG          12           5
# 2                           Argentina  ARG          23          18
# 3                             Armenia  ARM           5           1
# 4                         Australasia  ANZ           2           3
# ..                                ...  ...         ...         ...
# 141                        Yugoslavia  YUG          16          26
# 142  Independent Olympic Participants  IOP           1           0
# 143                            Zambia  ZAM          12           0
# 144                          Zimbabwe  ZIM          12           3
# 145                        Mixed team  ZZX           3           8
#
#      SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# 0               0             2           0           0             0
# 1               2             8           3           0             0
# 2              24            28          18           0             0
# 3               2             9           6           0             0
# 4               4             5           0           0             0
# ..            ...           ...         ...         ...           ...
# 141            29            28          14           0             3
# 142             1             2           0           0             0
# 143             1             1           0           0             0
# 144             4             1           1           0             0
# 145             5             4           0           0             0
#
#      WinterBronze
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 141             1
# 142             0
# 143             0
# 144             0
# 145             0
#
# [146 rows x 10 columns]

# %% [markdown]
# # 2. แสดงจำนวนแถวและจำนวนคอลัมน์ของ medals

# %%
medals.shape
# Out:
# (146, 10)

# %%
row = medals.shape[0]
row
# Out:
# 146

# %%
col = medals.shape[1]
col
# Out:
# 10

# %% [markdown]
# # 3. ตรวจสอบว่ารหัสประเทศ (Code) ไม่มีซ้ำกันด้วย attribute is_unique

# %%
medals.Code.is_unique
# Out:
# True

# %% [markdown]
# # 4.ตั้งรหัสประเทศให้เป็น index
#   1.ลองใช้ method set_index()

# %%
medals = medals.set_index("Code")
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
# [146 rows x 9 columns]

# %% [markdown]
# # 5.แสดงคอลัมน์เหรียญทองโอลิมปิคฤดูร้อน (SummerGold)

# %%
medals.loc[:, "SummerGold"]
# Out:
# Code
# AFG     0
# ALG     5
# ARG    18
# ARM     1
# ANZ     3
#        ..
# YUG    26
# IOP     0
# ZAM     0
# ZIM     3
# ZZX     8
# Name: SummerGold, Length: 146, dtype: int64

# %% [markdown]
# # 6.แสดงข้อมูลของประเทศสหรัฐอเมริกา (USA)

# %%
medals.loc["USA", :]
# Out:
# Country         United States
# SummerGame                 26
# SummerGold                976
# SummerSilver              757
# SummerBronze              666
# WinterGame                 22
# WinterGold                 96
# WinterSilver              102
# WinterBronze               84
# Name: USA, dtype: object

# %% [markdown]
# # 7.แสดงเฉพาะข้อมูลของโอลิมปิคฤดูร้อนของทุกประเทศ (คอลัมน์ที่ขึ้นต้นด้วยคำว่า Summer)

# %%
medals.loc[:, medals.columns.str.startswith("Summer")]
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# ...          ...         ...           ...           ...
# YUG           16          26            29            28
# IOP            1           0             1             2
# ZAM           12           0             1             1
# ZIM           12           3             4             1
# ZZX            3           8             5             4
#
# [146 rows x 4 columns]

# %% [markdown]
# # 8.แสดงข้อมูลเหรียญทองของโอลิมปิกฤดูร้อนและฤดูหนาวของประเทศไทย (THA) สิงคโปร์ (SIN) และมาเลเซีย (MAS) แสดงชื่อประเทศด้วย

# %%
medals.loc[['THA', 'SIN', 'MAS'], medals.columns.str.endswith('Gold') | medals.columns.str.contains('Country')]
# Out:
#         Country  SummerGold  WinterGold
# Code
# THA    Thailand           7           0
# SIN   Singapore           0           0
# MAS    Malaysia           0           0

# %% [markdown]
# # 9.แสดงข้อมูลเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูร้อนของประเทศฝรั่งเศส (FRA) และสเปน (ESP) แสดงชื่อประเทศด้วย

# %%
medals.loc[['FRA', 'ESP'],
           (medals.columns.str.startswith('Summer') &
           (medals.columns.str.endswith('Silver') |
           medals.columns.str.endswith('Bronze'))) |
           medals.columns.str.contains('Country')
           ]
# Out:
#      Country  SummerSilver  SummerBronze
# Code
# FRA   France           223           246
# ESP    Spain            59            35

# %% [markdown]
# # 10.แสดงประเทศที่เข้าร่วมโอลิมปิคฤดูร้อนมากกว่า 24 ครั้ง

# %%
medals.loc[(medals.SummerGame + medals.WinterGame) > 24]
# Out:
#              Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# ARG        Argentina          23          18            24            28
# AUS        Australia          25         139           152           177
# AUT          Austria          26          18            33            35
# BEL          Belgium          25          37            52            53
# BRA           Brazil          21          23            30            55
# BUL         Bulgaria          19          51            85            78
# CAN           Canada          25          59            99           121
# CHI            Chile          22           2             7             4
# TCH   Czechoslovakia          16          49            49            45
# DEN          Denmark          26          43            68            68
# FIN          Finland          24         101            84           117
# FRA           France          27         202           223           246
# GER          Germany          15         174           182           217
# GBR    Great Britain          27         236           272           272
# GRE           Greece          27          30            42            39
# HUN          Hungary          25         167           144           165
# ISL          Iceland          19           0             2             2
# IND            India          23           9             6            11
# IRI             Iran          15          15            20            25
# IRL          Ireland          20           9             8            12
# ITA            Italy          26         198           166           185
# JPN            Japan          21         130           126           142
# KOR      South Korea          16          81            82            80
# LIB          Lebanon          16           0             2             2
# LIE    Liechtenstein          16           0             0             0
# LUX       Luxembourg          22           1             1             0
# MEX           Mexico          22          13            21            28
# MGL         Mongolia          12           2             9            13
# NED      Netherlands          25          77            85           104
# NZL      New Zealand          22          42            18            39
# NOR           Norway          24          56            49            43
# POL           Poland          20          64            82           125
# POR         Portugal          23           4             8            11
# ROU          Romania          20          88            94           119
# ESP            Spain          22          37            59            35
# SWE           Sweden          26         143           164           176
# SUI      Switzerland          27          47            73            65
# TUR           Turkey          21          39            25            24
# USA    United States          26         976           757           666
# YUG       Yugoslavia          16          26            29            28
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# ARG           18           0             0             0
# AUS           18           5             3             4
# AUT           22          59            78            81
# BEL           20           1             1             3
# BRA            7           0             0             0
# BUL           19           1             2             3
# CAN           22          62            56            52
# CHI           16           0             0             0
# TCH           16           2             8            15
# DEN           13           0             1             0
# FIN           22          42            62            57
# FRA           22          31            31            47
# GER           11          78            78            53
# GBR           22          10             4            12
# GRE           18           0             0             0
# HUN           22           0             2             4
# ISL           17           0             0             0
# IND            9           0             0             0
# IRI           10           0             0             0
# IRL            6           0             0             0
# ITA           22          37            34            43
# JPN           20          10            17            18
# KOR           17          26            17            10
# LIB           16           0             0             0
# LIE           18           2             2             5
# LUX            8           0             2             0
# MEX            8           0             0             0
# MGL           13           0             0             0
# NED           20          37            38            35
# NZL           15           0             1             0
# NOR           22         118           111           100
# POL           22           6             7             7
# POR            7           0             0             0
# ROU           20           0             0             1
# ESP           19           1             0             1
# SWE           22          50            40            54
# SUI           22          50            40            48
# TUR           16           0             0             0
# USA           22          96           102            84
# YUG           14           0             3             1

# %% [markdown]
# # 11.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญ

# %%
medals.loc[medals.SummerGold > 200]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# CHN           10          12            22            19
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# # 12.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญและเป็นเหรียญเงินมากกว่า 200 เหรียญ

# %%
medals.loc[(medals.SummerGold > 200) & (medals.SummerSilver > 200)]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# # 13.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินของโอลิมปิคฤดูหนาว

# %%
medals.loc[medals.WinterGold > medals.WinterSilver, : ]
# Out:
#                      Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AUS                Australia          25         139           152
# BLR                  Belarus           5          12            24
# CAN                   Canada          25          59            99
# EST                  Estonia          11           9             9
# EUA   United Team of Germany           3          28            54
# GDR             East Germany           5         153           129
# GBR            Great Britain          27         236           272
# ITA                    Italy          26         198           166
# KOR              South Korea          16          81            82
# NOR                   Norway          24          56            49
# RUS                   Russia           5         132           121
# URS             Soviet Union           9         395           319
# EUN             Unified Team           1          45            38
# ESP                    Spain          22          37            59
# SWE                   Sweden          26         143           164
# SUI              Switzerland          27          47            73
# UKR                  Ukraine           5          33            27
# UZB               Uzbekistan           5           5             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AUS            177          18           5             3             4
# BLR             39           6           6             4             5
# CAN            121          22          62            56            52
# EST             15           9           4             2             1
# EUA             36           3           8             6             5
# GDR            127           6          39            36            35
# GBR            272          22          10             4            12
# ITA            185          22          37            34            43
# KOR             80          17          26            17            10
# NOR             43          22         118           111           100
# RUS            142           6          49            40            35
# URS            296           9          78            57            59
# EUN             29           1           9             6             8
# ESP             35          19           1             0             1
# SWE            176          22          50            40            54
# SUI             65          22          50            40            48
# UKR             55           6           2             1             4
# UZB             10           6           1             0             0

# %% [markdown]
# # 14.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูหนาวรวมกัน

# %%
medals.loc[medals.WinterGold > (medals.WinterSilver + medals.WinterBronze), : ]
# Out:
#          Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# EST      Estonia          11           9             9            15
# UZB   Uzbekistan           5           5             5            10
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# EST            9           4             2             1
# UZB            6           1             0             0

# %% [markdown]
# # 15.แสดงข้อมูลโอลิมปิกฤดูร้อนเท่านั้นของประเทศที่ชื่อขึ้นต้นด้วย 'A' ทั้งหมด
#    1.ลองใช้ method str.startswith() ร่วมกับการ slice

# %%
medals.loc[medals.Country.str.startswith('A') , :]
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG   Afghanistan          13           0             0             2
# ALG       Algeria          12           5             2             8
# ARG     Argentina          23          18            24            28
# ARM       Armenia           5           1             2             9
# ANZ   Australasia           2           3             4             5
# AUS     Australia          25         139           152           177
# AUT       Austria          26          18            33            35
# AZE    Azerbaijan           5           6             5            15
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AFG            0           0             0             0
# ALG            3           0             0             0
# ARG           18           0             0             0
# ARM            6           0             0             0
# ANZ            0           0             0             0
# AUS           18           5             3             4
# AUT           22          59            78            81
# AZE            5           0             0             0

# %% [markdown]
# # 16.ประเทศที่เข้าร่วมจำนวนโอลิมปิกฤดูร้อนมากที่สุดคือกี่ครั้ง

# %%
maxParticipated = medals.SummerGame.max()
maxParticipated
# Out:
# 27

# %% [markdown]
# # 17.แสดงชื่อประเทศที่เข้าร่วมโอลิมปิกฤดูร้อนมากที่สุด (ระวัง!! อาจมีหลายประเทศ)

# %%
medals.loc[medals.SummerGame == maxParticipated]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# SUI           22          50            40            48

# %% [markdown]
# # 18.จำนวนประเทศที่เข้าร่วมโอลิมปิกฤดูหนาวบ่อยที่สุดมีกี่ประเทศ

# %%
len(medals.loc[medals.WinterGame == medals.WinterGame.max()])
# Out:
# 12

# %% [markdown]
# # 19.จำนวนเหรียญทั้งหมดที่แจกไปในโอลิมปิกฤดูหนาวรวมแล้วมีกี่เหรียญ

# %%
sum(medals.WinterGold + medals.WinterSilver + medals.WinterBronze)
# Out:
# 2865

# %% [markdown]
# # 20.หาค่าเฉลี่ยของจำนวนเหรียญทองฤดูหนาวและฤดูร้อนต่อประเทศ

# %%
medals.loc[ : , ["WinterGold", "SummerGold"]].mean(axis = 1)
# Out:
# Code
# AFG     0.0
# ALG     2.5
# ARG     9.0
# ARM     0.5
# ANZ     1.5
#        ...
# YUG    13.0
# IOP     0.0
# ZAM     0.0
# ZIM     1.5
# ZZX     4.0
# Length: 146, dtype: float64

# %% [markdown]
# #21.แสดงจำนวนเหรียญทั้งหมด(รวมฤดูร้อนและฤดูหนาว)ที่แต่ละประเทศได้

# %%
medals['TotalMedals'] = medals.loc[ : , "SummerGold":"SummerBronze"].sum(axis = 1) + medals.loc[ : , "WinterGold":"WinterBronze"].sum(axis = 1)
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalMedals
# Code
# AFG             2
# ALG            15
# ARG            70
# ARM            12
# ANZ            12
# ...           ...
# YUG            87
# IOP             3
# ZAM             2
# ZIM             8
# ZZX            17
#
# [146 rows x 10 columns]

# %% [markdown]
# #22.แสดงประเทศที่ได้เหรียญรวมทุกประเภทของโอลิมปิกฤดูหนาวมากกว่าเหรียญรวมโอลิมปิกฤดูร้อนให้คอลัมน์ของตารางนี้แสดงชื่อประเทศเหรียญรวมฤดูร้อนเหรียญรวมฤดูหนาว

# %%
medals['SummerMedals'] = medals.loc[ : , "SummerGold":"SummerBronze"].sum(axis = 1)
medals['WinterMedals'] = medals.loc[ : , "WinterGold":"WinterBronze"].sum(axis = 1)
medals.loc[medals.WinterMedals > medals.SummerMedals, : ]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AUT         Austria          26          18            33            35
# LIE   Liechtenstein          16           0             0             0
# NOR          Norway          24          56            49            43
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalMedals  \
# Code
# AUT           22          59            78            81          304
# LIE           18           2             2             5            9
# NOR           22         118           111           100          477
#
#       SummerMedals  WinterMedals
# Code
# AUT             86           218
# LIE              0             9
# NOR            148           329

# %% [markdown]
# #23.แสดงประเทศที่ไม่เคยได้เหรียญใดของโอลิมปิกฤดูร้อนแต่ได้เหรียญใดของฤดูหนาวหรือได้แต่เหรียญฤดูร้อนไม่เคยได้ฤดูหนาว

# %%
medals.loc[((medals.WinterMedals == 0) & (medals.SummerMedals > 0)) |
            ((medals.WinterMedals > 0) & (medals.SummerMedals == 0))
            , : ].tail(100)
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# AZE                         Azerbaijan           5           6             5
# BAH                            Bahamas          15           5             2
# ...                                ...         ...         ...           ...
# ISV                     Virgin Islands          11           0             1
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# AZE             15           5           0             0             0
# BAH              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# ISV              0           7           0             0             0
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalMedals  SummerMedals  WinterMedals
# Code
# ARG            70            70             0
# ARM            12            12             0
# ANZ            12            12             0
# AZE            26            26             0
# BAH            12            12             0
# ...           ...           ...           ...
# ISV             1             1             0
# IOP             3             3             0
# ZAM             2             2             0
# ZIM             8             8             0
# ZZX            17            17             0
#
# [100 rows x 12 columns]

# %% [markdown]
# #24.แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากน้อยไปมาก

# %%
medals.sort_values("SummerGold", ascending = True)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG     Afghanistan          13           0             0             2
# NAM         Namibia           6           0             4             0
# MNE      Montenegro           2           0             1             0
# MDA         Moldova           5           0             2             5
# MRI       Mauritius           8           0             0             1
# ...             ...         ...         ...           ...           ...
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalMedals  \
# Code
# AFG            0           0             0             0            2
# NAM            0           0             0             0            4
# MNE            2           0             0             0            1
# MDA            6           0             0             0            7
# MRI            0           0             0             0            1
# ...          ...         ...           ...           ...          ...
# CHN           10          12            22            19          526
# FRA           22          31            31            47          780
# GBR           22          10             4            12          806
# URS            9          78            57            59         1204
# USA           22          96           102            84         2681
#
#       SummerMedals  WinterMedals
# Code
# AFG              2             0
# NAM              4             0
# MNE              1             0
# MDA              7             0
# MRI              1             0
# ...            ...           ...
# CHN            473            53
# FRA            671           109
# GBR            780            26
# URS           1010           194
# USA           2399           282
#
# [146 rows x 12 columns]

# %% [markdown]
# #25.แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากมากไปน้อยถ้าได้เหรียญทองฤดูร้อนเท่ากันให้เรียงตามจำนวนการเข้าแข่งฤดูร้อนจากน้อยไปมาก

# %%
medals.sort_values(["SummerGold", "SummerGame"], ascending = [False, True])
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GBR   Great Britain          27         236           272           272
# FRA          France          27         202           223           246
# CHN           China           9         201           146           126
# ...             ...         ...         ...           ...           ...
# SRI       Sri Lanka          16           0             2             0
# BER         Bermuda          17           0             0             1
# PUR     Puerto Rico          17           0             2             6
# ISL         Iceland          19           0             2             2
# PHI     Philippines          20           0             2             7
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalMedals  \
# Code
# USA           22          96           102            84         2681
# URS            9          78            57            59         1204
# GBR           22          10             4            12          806
# FRA           22          31            31            47          780
# CHN           10          12            22            19          526
# ...          ...         ...           ...           ...          ...
# SRI            0           0             0             0            2
# BER            7           0             0             0            1
# PUR            6           0             0             0            8
# ISL           17           0             0             0            4
# PHI            4           0             0             0            9
#
#       SummerMedals  WinterMedals
# Code
# USA           2399           282
# URS           1010           194
# GBR            780            26
# FRA            671           109
# CHN            473            53
# ...            ...           ...
# SRI              2             0
# BER              1             0
# PUR              8             0
# ISL              4             0
# PHI              9             0
#
# [146 rows x 12 columns]

# %% [markdown]
# #26.ให้สร้างคอลัมน์ใหม่ในตาราง medals ให้ชื่อว่า score โดยคำนวณคะแนนรวมจากเหรียญที่แต่ละประเทศได้(ทั้งฤดูร้อนและหนาว) โดยให้เหรียญทองได้ 3 คะแนนเหรียญเงินได้ 2 คะแนนเหรียญทองแดงได้ 1 คะแนนแล้วแสดงข้อมูล 10 ประเทศแรกที่ได้คะแนนเยอะที่สุด

# %%
medals['Score'] = (medals.SummerGold + medals.WinterGold) * 3 + (medals.SummerSilver + medals.WinterSilver) * 2 + (medals.SummerBronze + medals.WinterBronze) * 1
medals.sort_values('Score', ascending = False).head(10)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GBR   Great Britain          27         236           272           272
# GER         Germany          15         174           182           217
# FRA          France          27         202           223           246
# ITA           Italy          26         198           166           185
# SWE          Sweden          26         143           164           176
# CHN           China           9         201           146           126
# GDR    East Germany           5         153           129           127
# RUS          Russia           5         132           121           142
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalMedals  \
# Code
# USA           22          96           102            84         2681
# URS            9          78            57            59         1204
# GBR           22          10             4            12          806
# GER           11          78            78            53          782
# FRA           22          31            31            47          780
# ITA           22          37            34            43          663
# SWE           22          50            40            54          627
# CHN           10          12            22            19          526
# GDR            6          39            36            35          519
# RUS            6          49            40            35          519
#
#       SummerMedals  WinterMedals  Score
# Code
# USA           2399           282   5684
# URS           1010           194   2526
# GBR            780            26   1574
# GER            573           209   1546
# FRA            671           109   1500
# ITA            549           114   1333
# SWE            483           144   1217
# CHN            473            53   1120
# GDR            409           110   1068
# RUS            395           124   1042

# %% [markdown]
# #27.การเปรียบเทียบคะแนนจากเหรียญทั้งหมดอาจจะไม่แฟร์เพราะแต่ละประเทศเข้าร่วมการแข่งขันไม่เท่ากันดังนั้นให้สร้างคอลัมน์ใหม่ในตาราง medals ชื่อว่า perGame โดยคำนวณคะแนนต่อการเข้าร่วมแข่งขัน(คะแนนคำนวณเหมือนเดิมแต่หารด้วยจำนวนเกมส์ที่เข้าแข่งขันแยกกันระหว่างฤดูร้อนกับฤดูหนาวค่าperGame จะเป็นผลบวกของคะแนนของฤดูร้อนกับฤดูหนาว) แสดงข้อมูล 10 ประเทศที่ได้คะแนนน้อยที่สุด
# 1.ระวังตรวจสอบผลลัพธ์ให้ดีมี surprise นะข้อนี้

# %%
summer = ((medals.SummerGold) * 3 + (medals.SummerSilver) * 2 + (medals.SummerBronze) * 1) / medals.SummerGame
winter = ((medals.WinterGold) * 3 + (medals.WinterSilver) * 2 + (medals.WinterBronze) * 1) / medals.WinterGame
medals['perGame'] = summer.add(winter, fill_value = 0)
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalMedals  SummerMedals  WinterMedals  Score    perGame
# Code
# AFG             2             2             0      2   0.153846
# ALG            15            15             0     27   2.250000
# ARG            70            70             0    130   5.652174
# ARM            12            12             0     16   3.200000
# ANZ            12            12             0     22  11.000000
# ...           ...           ...           ...    ...        ...
# YUG            87            83             4    171  10.750000
# IOP             3             3             0      4   4.000000
# ZAM             2             2             0      3   0.250000
# ZIM             8             8             0     18   1.500000
# ZZX            17            17             0     38  12.666667
#
# [146 rows x 14 columns]
