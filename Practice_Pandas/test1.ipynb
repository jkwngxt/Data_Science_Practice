# %% [markdown]
# **นางสาวจิตรลดา โยธินทะ 6510405377**

# %% [markdown]
# # 1. โหลดไฟล์ที่ชื่อ olympic_cleaned.csv ขึ้นมาใน DataFrame ที่ชื่อ medals

# %%
import pandas as pd

# %%
medals = pd.read_csv('olympics_cleaned.csv')
medals
# Out:
#                               Country Code  SummerGame  SummerGold  \
# 0                         Afghanistan  AFG          13           0
# 1                             Algeria  ALG          12           5
# 2                           Argentina  ARG          23          18
# 3                             Armenia  ARM           5           1
# 4                         Australasia  ANZ           2           3
# ..                                ...  ...         ...         ...
# 141                        Yugoslavia  YUG          16          26
# 142  Independent Olympic Participants  IOP           1           0
# 143                            Zambia  ZAM          12           0
# 144                          Zimbabwe  ZIM          12           3
# 145                        Mixed team  ZZX           3           8
#
#      SummerSilver  SummerBronze  WinterGame  WinterGold  WinterSilver  \
# 0               0             2           0           0             0
# 1               2             8           3           0             0
# 2              24            28          18           0             0
# 3               2             9           6           0             0
# 4               4             5           0           0             0
# ..            ...           ...         ...         ...           ...
# 141            29            28          14           0             3
# 142             1             2           0           0             0
# 143             1             1           0           0             0
# 144             4             1           1           0             0
# 145             5             4           0           0             0
#
#      WinterBronze
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 141             1
# 142             0
# 143             0
# 144             0
# 145             0
#
# [146 rows x 10 columns]

# %% [markdown]
# # 2. แสดงจำนวนแถวและจำนวนคอลัมน์ของ medals

# %%
print('Row =', medals.shape[0], "\nColumn =", medals.shape[1])
# Out:
# Row = 146
# Column = 10

# %% [markdown]
# # 3. ตรวจสอบว่ารหัสประเทศ (Code) ไม่มีซ้ำกันด้วย attribute is_unique

# %%
medals.Code.is_unique
# Out:
# True

# %% [markdown]
# # 4.ตั้งรหัสประเทศให้เป็น index
#   1.ลองใช้ method set_index()

# %%
medals = medals.set_index('Code')
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
# [146 rows x 9 columns]

# %% [markdown]
# # 5.แสดงคอลัมน์เหรียญทองโอลิมปิคฤดูร้อน (SummerGold)

# %%
medals.SummerGold
# Out:
# Code
# AFG     0
# ALG     5
# ARG    18
# ARM     1
# ANZ     3
#        ..
# YUG    26
# IOP     0
# ZAM     0
# ZIM     3
# ZZX     8
# Name: SummerGold, Length: 146, dtype: int64

# %% [markdown]
# # 6.แสดงข้อมูลของประเทศสหรัฐอเมริกา (USA)

# %%
medals.loc['USA', :]
# Out:
# Country         United States
# SummerGame                 26
# SummerGold                976
# SummerSilver              757
# SummerBronze              666
# WinterGame                 22
# WinterGold                 96
# WinterSilver              102
# WinterBronze               84
# Name: USA, dtype: object

# %% [markdown]
# # 7.แสดงเฉพาะข้อมูลของโอลิมปิคฤดูร้อนของทุกประเทศ (คอลัมน์ที่ขึ้นต้นด้วยคำว่า Summer)

# %%
medals.loc[:, 'SummerGame' : 'SummerBronze']
# Out:
#       SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG           13           0             0             2
# ALG           12           5             2             8
# ARG           23          18            24            28
# ARM            5           1             2             9
# ANZ            2           3             4             5
# ...          ...         ...           ...           ...
# YUG           16          26            29            28
# IOP            1           0             1             2
# ZAM           12           0             1             1
# ZIM           12           3             4             1
# ZZX            3           8             5             4
#
# [146 rows x 4 columns]

# %% [markdown]
# # 8.แสดงข้อมูลเหรียญทองของโอลิมปิกฤดูร้อนและฤดูหนาวของประเทศไทย (THA) สิงคโปร์ (SIN) และมาเลเซีย (MAS) แสดงชื่อประเทศด้วย

# %%
medals.loc[['THA', 'SIN', 'MAS'], ['Country','SummerGold','WinterGold']]
# Out:
#         Country  SummerGold  WinterGold
# Code
# THA    Thailand           7           0
# SIN   Singapore           0           0
# MAS    Malaysia           0           0

# %% [markdown]
# # 9.แสดงข้อมูลเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูร้อนของประเทศฝรั่งเศส (FRA) และสเปน (ESP) แสดงชื่อประเทศด้วย

# %%
medals.loc[['FRA', 'ESP'], ['Country','SummerGold','SummerSilver']]
# Out:
#      Country  SummerGold  SummerSilver
# Code
# FRA   France         202           223
# ESP    Spain          37            59

# %% [markdown]
# # 10.แสดงประเทศที่เข้าร่วมโอลิมปิคฤดูร้อนมากกว่า 24 ครั้ง

# %%
medals.loc[medals.SummerGame > 24]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AUS       Australia          25         139           152           177
# AUT         Austria          26          18            33            35
# BEL         Belgium          25          37            52            53
# CAN          Canada          25          59            99           121
# DEN         Denmark          26          43            68            68
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# HUN         Hungary          25         167           144           165
# ITA           Italy          26         198           166           185
# NED     Netherlands          25          77            85           104
# SWE          Sweden          26         143           164           176
# SUI     Switzerland          27          47            73            65
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# AUS           18           5             3             4
# AUT           22          59            78            81
# BEL           20           1             1             3
# CAN           22          62            56            52
# DEN           13           0             1             0
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# HUN           22           0             2             4
# ITA           22          37            34            43
# NED           20          37            38            35
# SWE           22          50            40            54
# SUI           22          50            40            48
# USA           22          96           102            84

# %% [markdown]
# # 11.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญ

# %%
medals.loc[medals.SummerGold > 200]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# CHN           10          12            22            19
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# # 12.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูร้อนมากกว่า 200 เหรียญและเป็นเหรียญเงินมากกว่า 200 เหรียญ

# %%
medals.loc[(medals.SummerGold > 200) & (medals.SummerSilver > 200)]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# URS            9          78            57            59
# USA           22          96           102            84

# %% [markdown]
# # 13.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินของโอลิมปิคฤดูหนาว

# %%
medals.loc[medals.SummerGold > medals.WinterSilver]
# Out:
#           Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# ALG       Algeria          12           5             2             8
# ARG     Argentina          23          18            24            28
# ARM       Armenia           5           1             2             9
# ANZ   Australasia           2           3             4             5
# AUS     Australia          25         139           152           177
# ...           ...         ...         ...           ...           ...
# UZB    Uzbekistan           5           5             5            10
# VEN     Venezuela          17           2             2             8
# YUG    Yugoslavia          16          26            29            28
# ZIM      Zimbabwe          12           3             4             1
# ZZX    Mixed team           3           8             5             4
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# ALG            3           0             0             0
# ARG           18           0             0             0
# ARM            6           0             0             0
# ANZ            0           0             0             0
# AUS           18           5             3             4
# ...          ...         ...           ...           ...
# UZB            6           1             0             0
# VEN            4           0             0             0
# YUG           14           0             3             1
# ZIM            1           0             0             0
# ZZX            0           0             0             0
#
# [93 rows x 9 columns]

# %% [markdown]
# # 14.แสดงประเทศที่ได้เหรียญทองของโอลิมปิคฤดูหนาวมากกว่าเหรียญเงินและเหรียญทองแดงของโอลิมปิคฤดูหนาวรวมกัน

# %%
medals.loc[medals.WinterGold > (medals.WinterSilver + medals.WinterBronze)]
# Out:
#          Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# EST      Estonia          11           9             9            15
# UZB   Uzbekistan           5           5             5            10
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# EST            9           4             2             1
# UZB            6           1             0             0

# %% [markdown]
# # 15.แสดงข้อมูลโอลิมปิกฤดูร้อนเท่านั้นของประเทศที่ชื่อขึ้นต้นด้วย 'A' ทั้งหมด
#    1.ลองใช้ method str.startswith() ร่วมกับการ slice

# %%
medals.loc[medals.Country.str.contains('A'), 
           medals.columns.str.contains('Summer') | (medals.columns == 'Country')]
# Out:
#                    Country  SummerGame  SummerGold  SummerSilver  SummerBronze
# Code
# AFG            Afghanistan          13           0             0             2
# ALG                Algeria          12           5             2             8
# ARG              Argentina          23          18            24            28
# ARM                Armenia           5           1             2             9
# ANZ            Australasia           2           3             4             5
# AUS              Australia          25         139           152           177
# AUT                Austria          26          18            33            35
# AZE             Azerbaijan           5           6             5            15
# AHO   Netherlands Antilles          13           0             1             0
# KSA           Saudi Arabia          10           0             1             2
# RSA           South Africa          18          23            26            27
# UAE   United Arab Emirates           8           1             0             0

# %% [markdown]
# # 16.ประเทศที่เข้าร่วมจำนวนโอลิมปิกฤดูร้อนมากที่สุดคือกี่ครั้ง

# %%
medals.SummerGame.max()
# Out:
# 27

# %% [markdown]
# # 17.แสดงชื่อประเทศที่เข้าร่วมโอลิมปิกฤดูร้อนมากที่สุด (ระวัง!! อาจมีหลายประเทศ)

# %%
medals.loc[medals.SummerGame == medals.SummerGame.max()]
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# GRE          Greece          27          30            42            39
# SUI     Switzerland          27          47            73            65
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze
# Code
# FRA           22          31            31            47
# GBR           22          10             4            12
# GRE           18           0             0             0
# SUI           22          50            40            48

# %% [markdown]
# # 18.จำนวนประเทศที่เข้าร่วมโอลิมปิกฤดูหนาวบ่อยที่สุดมีกี่ประเทศ

# %%
medals.WinterGame.max()
# Out:
# 22

# %% [markdown]
# # 19.จำนวนเหรียญทั้งหมดที่แจกไปในโอลิมปิกฤดูหนาวรวมแล้วมีกี่เหรียญ

# %%
medals.WinterGold.sum() + medals.WinterSilver.sum() + medals.WinterBronze.sum()
# Out:
# 2865

# %% [markdown]
# # 20.หาค่าเฉลี่ยของจำนวนเหรียญทองฤดูหนาวและฤดูร้อนต่อประเทศ

# %%
medals.loc[:, ['WinterGold', 'SummerGold']].mean(axis = 1)
# Out:
# Code
# AFG     0.0
# ALG     2.5
# ARG     9.0
# ARM     0.5
# ANZ     1.5
#        ...
# YUG    13.0
# IOP     0.0
# ZAM     0.0
# ZIM     1.5
# ZZX     4.0
# Length: 146, dtype: float64

# %% [markdown]
# # 21.แสดงจำนวนเหรียญทั้งหมด(รวมฤดูร้อนและฤดูหนาว)ที่แต่ละประเทศได้

# %%
medals.loc[:, ~ (medals.columns.str.contains('Game') | (medals.columns == 'Country'))].sum(axis = 1)
# Out:
# Code
# AFG     2
# ALG    15
# ARG    70
# ARM    12
# ANZ    12
#        ..
# YUG    87
# IOP     3
# ZAM     2
# ZIM     8
# ZZX    17
# Length: 146, dtype: int64

# %% [markdown]
# # 22.แสดงประเทศที่ได้เหรียญรวมทุกประเภทของโอลิมปิกฤดูหนาวมากกว่าเหรียญรวมโอลิมปิกฤดูร้อนให้คอลัมน์ของตารางนี้แสดงชื่อประเทศเหรียญรวมฤดูร้อนเหรียญรวมฤดูหนาว

# %%
medals['TotalSummer'] = medals.loc[ : , 'SummerGold' : 'SummerBronze'].sum(axis = 1)
medals['TotalWinter'] = medals.loc[ : , 'WinterGold' : 'WinterBronze'].sum(axis = 1)
medals['TotalMedal'] = medals['TotalWinter'] + medals['TotalSummer']
medals.loc[medals['TotalWinter'] > medals['TotalSummer'], ['Country', 'TotalWinter', 'TotalSummer']]
# Out:
#             Country  TotalWinter  TotalSummer
# Code
# AUT         Austria          218           86
# LIE   Liechtenstein            9            0
# NOR          Norway          329          148

# %% [markdown]
# # 23.แสดงประเทศที่ไม่เคยได้เหรียญใดของโอลิมปิกฤดูร้อนแต่ได้เหรียญใดของฤดูหนาวหรือได้แต่เหรียญฤดูร้อนไม่เคยได้ฤดูหนาว

# %%
medals.loc[((medals['TotalWinter'] > 0) & (medals['TotalSummer'] == 0)) |
           ((medals['TotalWinter'] == 0) & (medals['TotalSummer'] > 0)) 
           , :]
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# ISV                     Virgin Islands          11           0             1
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# ISV              0           7           0             0             0
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalSummer  TotalWinter  TotalMedal
# Code
# AFG             2            0           2
# ALG            15            0          15
# ARG            70            0          70
# ARM            12            0          12
# ANZ            12            0          12
# ...           ...          ...         ...
# ISV             1            0           1
# IOP             3            0           3
# ZAM             2            0           2
# ZIM             8            0           8
# ZZX            17            0          17
#
# [102 rows x 12 columns]

# %% [markdown]
# # 24.แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากน้อยไปมาก

# %%
medals.sort_values('SummerGold', ascending = True)
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# AFG     Afghanistan          13           0             0             2
# NAM         Namibia           6           0             4             0
# MNE      Montenegro           2           0             1             0
# MDA         Moldova           5           0             2             5
# MRI       Mauritius           8           0             0             1
# ...             ...         ...         ...           ...           ...
# CHN           China           9         201           146           126
# FRA          France          27         202           223           246
# GBR   Great Britain          27         236           272           272
# URS    Soviet Union           9         395           319           296
# USA   United States          26         976           757           666
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalSummer  \
# Code
# AFG            0           0             0             0            2
# NAM            0           0             0             0            4
# MNE            2           0             0             0            1
# MDA            6           0             0             0            7
# MRI            0           0             0             0            1
# ...          ...         ...           ...           ...          ...
# CHN           10          12            22            19          473
# FRA           22          31            31            47          671
# GBR           22          10             4            12          780
# URS            9          78            57            59         1010
# USA           22          96           102            84         2399
#
#       TotalWinter  TotalMedal
# Code
# AFG             0           2
# NAM             0           4
# MNE             0           1
# MDA             0           7
# MRI             0           1
# ...           ...         ...
# CHN            53         526
# FRA           109         780
# GBR            26         806
# URS           194        1204
# USA           282        2681
#
# [146 rows x 12 columns]

# %% [markdown]
# # 25.แสดงประเทศเรียงลำดับตามเหรียญทองฤดูร้อนจากมากไปน้อยถ้าได้เหรียญทองฤดูร้อนเท่ากันให้เรียงตามจำนวนการเข้าแข่งฤดูร้อนจากน้อยไปมาก

# %%
medals.sort_values(['SummerGold','SummerGame'], ascending = [False, True])
# Out:
#             Country  SummerGame  SummerGold  SummerSilver  SummerBronze  \
# Code
# USA   United States          26         976           757           666
# URS    Soviet Union           9         395           319           296
# GBR   Great Britain          27         236           272           272
# FRA          France          27         202           223           246
# CHN           China           9         201           146           126
# ...             ...         ...         ...           ...           ...
# SRI       Sri Lanka          16           0             2             0
# BER         Bermuda          17           0             0             1
# PUR     Puerto Rico          17           0             2             6
# ISL         Iceland          19           0             2             2
# PHI     Philippines          20           0             2             7
#
#       WinterGame  WinterGold  WinterSilver  WinterBronze  TotalSummer  \
# Code
# USA           22          96           102            84         2399
# URS            9          78            57            59         1010
# GBR           22          10             4            12          780
# FRA           22          31            31            47          671
# CHN           10          12            22            19          473
# ...          ...         ...           ...           ...          ...
# SRI            0           0             0             0            2
# BER            7           0             0             0            1
# PUR            6           0             0             0            8
# ISL           17           0             0             0            4
# PHI            4           0             0             0            9
#
#       TotalWinter  TotalMedal
# Code
# USA           282        2681
# URS           194        1204
# GBR            26         806
# FRA           109         780
# CHN            53         526
# ...           ...         ...
# SRI             0           2
# BER             0           1
# PUR             0           8
# ISL             0           4
# PHI             0           9
#
# [146 rows x 12 columns]

# %% [markdown]
# # 26.ให้สร้างคอลัมน์ใหม่ในตาราง medals ให้ชื่อว่า score โดยคำนวณคะแนนรวมจากเหรียญที่แต่ละประเทศได้(ทั้งฤดูร้อนและหนาว) โดยให้เหรียญทองได้ 3 คะแนนเหรียญเงินได้ 2 คะแนนเหรียญทองแดงได้ 1 คะแนนแล้วแสดงข้อมูล 10 ประเทศแรกที่ได้คะแนนเยอะที่สุด

# %%
medals['Score'] = (medals.SummerGold + medals.WinterGold) * 3 + (medals.SummerSilver + medals.WinterSilver) * 2 + medals.WinterBronze + medals.SummerBronze
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalSummer  TotalWinter  TotalMedal  Score
# Code
# AFG             2            0           2      2
# ALG            15            0          15     27
# ARG            70            0          70    130
# ARM            12            0          12     16
# ANZ            12            0          12     22
# ...           ...          ...         ...    ...
# YUG            83            4          87    171
# IOP             3            0           3      4
# ZAM             2            0           2      3
# ZIM             8            0           8     18
# ZZX            17            0          17     38
#
# [146 rows x 13 columns]

# %% [markdown]
# # 27.การเปรียบเทียบคะแนนจากเหรียญทั้งหมดอาจจะไม่แฟร์เพราะแต่ละประเทศเข้าร่วมการแข่งขันไม่เท่ากันดังนั้นให้สร้างคอลัมน์ใหม่ในตาราง medals ชื่อว่า perGame โดยคำนวณคะแนนต่อการเข้าร่วมแข่งขัน(คะแนนคำนวณเหมือนเดิมแต่หารด้วยจำนวนเกมส์ที่เข้าแข่งขันแยกกันระหว่างฤดูร้อนกับฤดูหนาวค่าperGame จะเป็นผลบวกของคะแนนของฤดูร้อนกับฤดูหนาว) แสดงข้อมูล 10 ประเทศที่ได้คะแนนน้อยที่สุด
# 1.ระวังตรวจสอบผลลัพธ์ให้ดีมี surprise นะข้อนี้

# %%
ScoreSummer = ((medals.SummerGold) * 3 + (medals.SummerSilver ) * 2  + medals.SummerBronze) / medals.SummerGame
ScoreWinter = (( medals.WinterGold) * 3 + ( medals.WinterSilver) * 2 + medals.WinterBronze) / medals.WinterGame
medals['perGame'] = ScoreSummer.fillna(0) +  ScoreWinter.fillna(0)
medals
# Out:
#                                Country  SummerGame  SummerGold  SummerSilver  \
# Code
# AFG                        Afghanistan          13           0             0
# ALG                            Algeria          12           5             2
# ARG                          Argentina          23          18            24
# ARM                            Armenia           5           1             2
# ANZ                        Australasia           2           3             4
# ...                                ...         ...         ...           ...
# YUG                         Yugoslavia          16          26            29
# IOP   Independent Olympic Participants           1           0             1
# ZAM                             Zambia          12           0             1
# ZIM                           Zimbabwe          12           3             4
# ZZX                         Mixed team           3           8             5
#
#       SummerBronze  WinterGame  WinterGold  WinterSilver  WinterBronze  \
# Code
# AFG              2           0           0             0             0
# ALG              8           3           0             0             0
# ARG             28          18           0             0             0
# ARM              9           6           0             0             0
# ANZ              5           0           0             0             0
# ...            ...         ...         ...           ...           ...
# YUG             28          14           0             3             1
# IOP              2           0           0             0             0
# ZAM              1           0           0             0             0
# ZIM              1           1           0             0             0
# ZZX              4           0           0             0             0
#
#       TotalSummer  TotalWinter  TotalMedal  Score    perGame
# Code
# AFG             2            0           2      2   0.153846
# ALG            15            0          15     27   2.250000
# ARG            70            0          70    130   5.652174
# ARM            12            0          12     16   3.200000
# ANZ            12            0          12     22  11.000000
# ...           ...          ...         ...    ...        ...
# YUG            83            4          87    171  10.750000
# IOP             3            0           3      4   4.000000
# ZAM             2            0           2      3   0.250000
# ZIM             8            0           8     18   1.500000
# ZZX            17            0          17     38  12.666667
#
# [146 rows x 14 columns]
